# %% [markdown]
# # Table of Contents
#
# 0. [Import Libraries](#0.-Import-Libraries)
# 1. [Import Data](#1.-Import-Data)
# 2. [Data Exploration](#2.-Data-Exploration)
# 3. [Data Cleaning](#3.-Data-Cleaning)
# 4. [Data Preparation](#4.-Data-Preparation)
# 5. [Benchmark Model](#5.-Benchmark-Model)<br>
# 6. [Feature Engineering](#6.-Feature-Engineering)
# 7. [Model Training](#7.-Model-Training)<br>
#     7.1. [Decision Tree](#7.1.-Decision-Tree)<br>
#     7.2. [Random Forest](#7.2.-Random-Forest)<br>
#     7.3. [Comparing Algorithm Performances](#7.3.-Comparing-Algorithm-Performances)
# 8. [Tuning](#8.-Tuning)<br>

# %% [markdown]
# # 0. Import Libraries
# [back to top](#Table-of-Contents)

# %%
import pandas as pd
import numpy as np

# %%
pip install fastparquet
# Out:
# ...
#   Obtaining dependency information for fastparquet from https://files.pythonhosted.org/packages/18/9a/dd53412911f518a805c1cd03cc28699939b0a55e2c74063d5581c882d0a3/fastparquet-2026.3.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cramjam>=2.3 from https://files.pythonhosted.org/packages/a9/bd/102d6deb87a8524ac11cddcd31a7612b8f20bf9b473c3c645045e3b957c7/cramjam-2.11.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/669.4 kB ? eta -:--:--
#    -------------- ------------------------ 256.0/669.4 kB 16.4 MB/s eta 0:00:01
#    --------------------------------------  665.6/669.4 kB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 669.4/669.4 kB 8.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -------- ------------------------------- 0.4/1.7 MB 11.6 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 9.8 MB/s eta 0:00:01
# ...

# %% [markdown]
# # 1. Import Data
# [back to top](#Table-of-Contents)

# %%
taxi_df = pd.read_parquet('Data/yellow_tripdata_2019-01.parquet')

# %% [markdown]
# # 2. Data Exploration
# [back to top](#Table-of-Contents)

# %%
taxi_df.shape
# Out:
# (7696617, 19)

# %%
taxi_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# 1            2.6         1.0                  N           239           246
# 2            0.0         1.0                  N           236           236
# 3            0.0         1.0                  N           193           193
# 4            0.0         2.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
taxi_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %% [markdown]
# # 3. Data Cleaning
# [back to top](#Table-of-Contents)

# %% [markdown]
# # 4. Data Preparation
# [back to top](#Table-of-Contents)

# %% [markdown]
# # 5. Benchmark Model
# [back to top](#Table-of-Contents)

# %% [markdown]
# # 6. Feature Engineering
# [back to top](#Table-of-Contents)

# %% [markdown]
# # 7. Model Training
# [back to top](#Table-of-Contents)

# %% [markdown]
# ##   7.1. Decision Tree
# [back to top](#Table-of-Contents)

# %% [markdown]
# ## 7.2. Random Forest
# [back to top](#Table-of-Contents)

# %% [markdown]
# ## 7.3. Comparing Algorithm Performances
# [back to top](#Table-of-Contents)

# %% [markdown]
# # 8. Tuning
# [back to top](#Table-of-Contents)
